# %% [markdown]
# ### Crop requirement dataset analysis

# %% [markdown]
# # #Importing all libraries

# %%
#for manipulations
import pandas as pd
import numpy as np

#for data visualisations we use
import matplotlib.pyplot as plt
import seaborn as sb

#for interactivity
from ipywidgets import interact

# %% [markdown]
# **Reading a dataset**

# %%
data = pd.read_csv('Crop_recommendation.csv')
data
# Out:
#         N   P   K  Temperature   Humidity        ph    Rainfall   Label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %% [markdown]
# **check shape of dataset**

# %%
print("Shape of a dataset:",data.shape)
# Out:
# Shape of a dataset: (2200, 8)

# %% [markdown]
# **head and tail is used to check the first five rows and last five rows in the dataset**

# %%
data.head()
# Out:
#     N   P   K  Temperature   Humidity        ph    Rainfall Label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
data.tail()
# Out:
#         N   P   K  Temperature   Humidity        ph    Rainfall   Label
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee

# %% [markdown]
# # check if there is any missing value present in the dataset
# * isnull():used to check missing value in the dataset it gives either True or False,True means missing value is there in that column or row & False means no missing value
# * isnull().sum():this used to check total no of missing values in all columns of the dataset

# %%
data.isnull()
# Out:
#           N      P      K  Temperature  Humidity     ph  Rainfall  Label
# 0     False  False  False        False     False  False     False  False
# 1     False  False  False        False     False  False     False  False
# 2     False  False  False        False     False  False     False  False
# 3     False  False  False        False     False  False     False  False
# 4     False  False  False        False     False  False     False  False
# ...     ...    ...    ...          ...       ...    ...       ...    ...
# 2195  False  False  False        False     False  False     False  False
# 2196  False  False  False        False     False  False     False  False
# 2197  False  False  False        False     False  False     False  False
# 2198  False  False  False        False     False  False     False  False
# 2199  False  False  False        False     False  False     False  False
#
# [2200 rows x 8 columns]

# %%
data.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# Temperature    0
# Humidity       0
# ph             0
# Rainfall       0
# Label          0
# dtype: int64

# %% [markdown]
# # if missing values are present in dataset then we can use:
# * Fill-NA fuction is used to replace these missing values with statistical values such as Mean,Frequency,or Mode
# * pandas have function like fill-NA,drop-NA to handle the missing value

# %% [markdown]
# **Lets check the Crop present in this Dataset**
# * value_counts():used to get a series containing counts of unique values

# %%
data['Label'].value_counts()
# Out:
# grapes         100
# apple          100
# papaya         100
# pomegranate    100
# kidneybeans    100
# pigeonpeas     100
# mothbeans      100
# blackgram      100
# maize          100
# rice           100
# orange         100
# cotton         100
# mungbean       100
# jute           100
# chickpea       100
# watermelon     100
# lentil         100
# coconut        100
# banana         100
# coffee         100
# muskmelon      100
# mango          100
# Name: Label, dtype: int64

# %% [markdown]
# ### Check summary for all the crops
# #### This is help to find an average requirements of all the crop

# %%
print("Average Ratio of Nitrogen in the Soil : {0:.2f}".format(data['N'].mean()))
print("Average Ratio of Phosphorous in the Soil : {0:.2f}".format(data['P'].mean()))
print("Average Ratio of Potassium in the Soil : {0:.2f}".format(data['K'].mean()))
print("Average Temperature in celsius : {0:.2f}".format(data['Temperature'].mean()))
print("Average Relative Humidity in % : {0:.2f}".format(data['Humidity'].mean()))
print("Average PH value of the soil : {0:.2f}".format(data['ph'].mean()))
print("Average Rainfall in mm : {0:.2f}".format(data['Rainfall'].mean()))
# Out:
# Average Ratio of Nitrogen in the Soil : 50.55
# Average Ratio of Phosphorous in the Soil : 53.36
# Average Ratio of Potassium in the Soil : 48.15
# Average Temperature in celsius : 25.62
# Average Relative Humidity in % : 71.48
# Average PH value of the soil : 6.47
# Average Rainfall in mm : 103.46

# %% [markdown]
# ## Check the summary statistic for each of the crop
# ### This is help to find minimum,maximum and an average requirements for each of the crop present in the dataset
# * This problem statement i use @interact function to interact with the function

# %%
@interact
def summary(Crops = list(data['Label'].value_counts().index)):
    x = data[data['Label'] == Crops]
    print("---------------------------------------------------")
    print("Statistics for Nitrogen")
    print("Minimum Nitrogen required:",x['N'].min())
    print("Average Nitrogen required :",x['N'].mean())
    print("Maximum Nitrogen required :",x['N'].max())
    print("---------------------------------------------------")
    print("Statistics for Phosphorous")
    print("Minimum Phosphorous required:",x['P'].min())
    print("Average Phosphorous required :",x['P'].mean())
    print("Maximum Phosphorous required :",x['P'].max())
    print("---------------------------------------------------")
    print("Statistics for Potassium")
    print("Minimum potassium required:",x['K'].min())
    print("Average potassium required :",x['K'].mean())
    print("Maximum potassium required :",x['K'].max())
    print("---------------------------------------------------")
    print("Statistics for Temperature")
    print("Minimum Temperature required:",x['Temperature'].min())
    print("Average Temperature required :",x['Temperature'].mean())
    print("Maximum Temperature required :",x['Temperature'].max())
    print("---------------------------------------------------")
    print("Statistics for Humidity")
    print("Minimum  Humidity required:",x['Humidity'].min())
    print("Average  Humidity required :",x['Humidity'].mean())
    print("Maximum  Humidity required :",x['Humidity'].max())
    print("---------------------------------------------------")
    print("Statistics for PH")
    print("Minimum PH required:",x['ph'].min())
    print("Average PH required :",x['ph'].mean())
    print("Maximum PH required :",x['ph'].max())
    print("---------------------------------------------------")
    print("Statistics for Rainfall")
    print("Minimum Rainfall required:",x['Rainfall'].min())
    print("Average Rainfall required :",x['Rainfall'].mean())
    print("Maximum Rainfall required :",x['Rainfall'].max())
    print("...................................................")
# Out:
# interactive(children=(Dropdown(description='Crops', options=('grapes', 'apple', 'papaya', 'pomegranate', 'kidn…

# %% [markdown]
# ## Compare the average requirement for each crops with average conditions

# %%
@interact
def ccompare(conditions = ['N','P','K','Temperature','ph','Humidity','Rainfall']):
    print("Average Value For",conditions,"{0:.2f}".format(data[conditions].mean()))
    print("----------------------------------------------------------------------")
    print("RICE : {0:.2f}".format(data[(data['Label']=='rice')][conditions].mean()))
    print("------------------------------------------------------------------------")
    print("COFFEE : {0:.2f}".format(data[data['Label']=='coffee'][conditions].mean()))
    print("-----------------------------------------------------------------------")
    print("MAIZE: {0:.2f}".format(data[data['Label']=='maize'][conditions].mean()))
    print("------------------------------------------------------------------------")
    print("GRAPES : {0:.2f}".format(data[data['Label']=='grapes'][conditions].mean()))
    print("------------------------------------------------------------------------")
    print("CHICKPEA : {0:.2f}".format(data[data['Label']=='chickpea'][conditions].mean()))
    print("------------------------------------------------------------------------")
    print("MUNGBEAN : {0:.2f}".format(data[data['Label']=='mungbean'][conditions].mean()))
    print("------------------------------------------------------------------------")
    print("MANGO : {0:.2f}".format(data[data['Label']=='mango'][conditions].mean()))
    print("------------------------------------------------------------------------")
    print("POMEGRANATE : {0:.2f}".format(data[data['Label']=='pomegranate'][conditions].mean()))
    print("------------------------------------------------------------------------")
    print("PIGEONPEAS : {0:.2f}".format(data[data['Label']=='pigeonpeas'][conditions].mean()))
    print("------------------------------------------------------------------------")
    print("MOTHBEANS : {0:.2f}".format(data[data['Label']=='mothbeans'][conditions].mean()))
    print("------------------------------------------------------------------------")
    print("APPLE : {0:.2f}".format(data[data['Label']=='apple'][conditions].mean()))
    print("------------------------------------------------------------------------")
    print("BLACKGRAM : {0:.2f}".format(data[data['Label']=='blackgram'][conditions].mean()))
    print("------------------------------------------------------------------------")
    print("MUSKMELON: {0:.2f}".format(data[data['Label']=='muskmelon'][conditions].mean()))
    print("------------------------------------------------------------------------")
    print("KIDNEYBEANS : {0:.2f}".format(data[data['Label']=='kidneybeans'][conditions].mean()))
    print("------------------------------------------------------------------------")
    print("ORANGE : {0:.2f}".format(data[data['Label']=='orange'][conditions].mean()))
    print("------------------------------------------------------------------------")
    print("COTTON : {0:.2f}".format(data[data['Label']=='cotton'][conditions].mean()))
    print("------------------------------------------------------------------------")
    print("WATERMELON : {0:.2f}".format(data[data['Label']=='watermelon'][conditions].mean()))
    print("------------------------------------------------------------------------")
    print("COCONUT : {0:.2f}".format(data[data['Label']=='coconut'][conditions].mean()))
    print("------------------------------------------------------------------------")
    print("LENTIL : {0:.2f}".format(data[data['Label']=='lentil'][conditions].mean()))
    print("------------------------------------------------------------------------")
    print("JUTE : {0:.2f}".format(data[data['Label']=='jute'][conditions].mean()))
    print("------------------------------------------------------------------------")
    print("BANANA : {0:.2f}".format(data[data['Label']=='banana'][conditions].mean()))
    print("------------------------------------------------------------------------")
    print("PAPAYA : {0:.2f}".format(data[data['Label']=='papaya'][conditions].mean()))  
    print("------------------------------------------------------------------------")
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'Temperature', 'ph', 'Humidit…

# %%
@interact
def compare(Requirements = ['N','P','K','Temperature','ph','Humidity','Rainfall']):
    print("Crops which require greater than average",Requirements,'\n')
    print(data[data[Requirements]>data[Requirements].mean()]['Label'].unique())
    print("---------------------------------------------------------------------")
    print("Crops which require less than average",Requirements,'\n')
    print(data[data[Requirements]<=data[Requirements].mean()]['Label'].unique())
# Out:
# interactive(children=(Dropdown(description='Requirements', options=('N', 'P', 'K', 'Temperature', 'ph', 'Humid…

# %% [markdown]
# ### identify crops can only be Grown in Summer Season,Winter Season,and Rainy Season

# %%
print("Summer Season Crops")
print(data[(data['Temperature'] > 30) & (data['Humidity'] > 50)]['Label'].unique())
print("-------------------------------------")
print("Winter Season Crops")
print(data[(data['Temperature'] < 20) & (data['Humidity'] > 30)]['Label'].unique())
print("-------------------------------------")
print("Rainy Season Crops")
print(data[(data['Rainfall'] > 200) & (data['Humidity'] > 30)]['Label'].unique())
print("....................................................")
# Out:
# Summer Season Crops
# ['pigeonpeas' 'mothbeans' 'blackgram' 'mango' 'grapes' 'orange' 'papaya']
# -------------------------------------
# Winter Season Crops
# ['maize' 'pigeonpeas' 'lentil' 'pomegranate' 'grapes' 'orange']
# -------------------------------------
# Rainy Season Crops
# ['rice' 'papaya' 'coconut']
# ....................................................

# %% [markdown]
# ### Lets Find Out Relation Graphs

# %%
#Nitrogen relation with crops

plt.figure(figsize=(10,7))
plt.title(" nitrogen relation with crops")
sb.barplot(y="N",x="Label",data=data)
plt.xticks(rotation='vertical',fontsize=12)
plt.ylabel("Nitrogen")
plt.xlabel("Crops")
plt.grid()

# %%
#Phosphorus relation with crops

plt.figure(figsize=(10,7))
plt.title("Phosphorus relation with crops")
sb.barplot(y="P",x="Label",data=data,color='lawngreen')
plt.xticks(rotation='vertical',fontsize=12)
plt.ylabel("Phosphorus")
plt.xlabel("Crops")
plt.grid()

# %%
#Potassium relation with crops

plt.figure(figsize=(10,7))
plt.title("Potassium relation with crops")
sb.barplot(y="K",x="Label",data=data,color='purple')
plt.xticks(rotation='vertical',fontsize=12)
plt.ylabel("Potassium")
plt.xlabel("Crops")
plt.grid()

# %%
#Rainfall relation with crops

plt.figure(figsize=(10,7))
plt.title("Rainfall relation with crops")
sb.barplot(y="Rainfall",x="Label",data=data,color='deepskyblue')
plt.xticks(rotation='vertical',fontsize=12)
plt.ylabel("Rainfall")
plt.xlabel("Crops")
plt.grid()

# %%
#Temperature relation with crops

plt.figure(figsize=(10,7))
plt.title(" Temperature relation with crops")
sb.barplot(y="Temperature",x="Label",data=data,color='r')
plt.xticks(rotation='vertical',fontsize=12)
plt.ylabel("Temperature")
plt.xlabel("Crops")
plt.grid()

# %%
#Humidity relation with crops

plt.figure(figsize=(10,7))
plt.title(" Humidity relation with crops")
sb.barplot(y="Humidity",x="Label",data=data,color='orange')
plt.xticks(rotation='vertical',fontsize=12)
plt.ylabel("Humidity")
plt.xlabel("Crops")
plt.grid()

# %%
#ph relation with crops

plt.figure(figsize=(10,7))
plt.title(" ph relation with crops")
sb.barplot(y="ph",x="Label",data=data,color='')
plt.xticks(rotation='vertical',fontsize=12)
plt.ylabel("Ph")
plt.xlabel("Crops")
plt.grid()

# %%
print("Crop which required very high ratio of nitrogen content in soil:",data[data['N']>120]['Label'].unique())

print("-----------------------------------------------------------------------------------------------------")
print("Crop which required very high ratio of phosphorous content in soil:",data[data['P']>100]['Label'].unique())

print("-----------------------------------------------------------------------------------------------------")
print("Crop which required very high ratio of potassium content in soil:",data[data['K']>200]['Label'].unique())

print("-----------------------------------------------------------------------------------------------------")
print("Crop which required very high Rainfall:",data[data['Rainfall']>200]['Label'].unique())

print("-----------------------------------------------------------------------------------------------------")
print("Crop which required very high Temperature:",data[data['Temperature']>40]['Label'].unique())
print("-----------------------------------------------------------------------------------------------------")
print("Crop which required very low Temperature:",data[data['Temperature']<10]['Label'].unique())
print("-----------------------------------------------------------------------------------------------------")
print("Crop which required very high Humidity:",data[data['Humidity']>40]['Label'].unique())
print("-----------------------------------------------------------------------------------------------------")
print("Crop which required very low Humidity:",data[data['Humidity']<20]['Label'].unique())
print("-----------------------------------------------------------------------------------------------------")
print("Crop which required very low ph:",data[data['ph']<4]['Label'].unique())
print("-----------------------------------------------------------------------------------------------------")
print("Crop which required very high ph:",data[data['ph']>9]['Label'].unique())
print("-----------------------------------------------------------------------------------------------------")
# Out:
# Crop which required very high ratio of nitrogen content in soil: ['cotton']
# -----------------------------------------------------------------------------------------------------
# Crop which required very high ratio of phosphorous content in soil: ['grapes' 'apple']
# -----------------------------------------------------------------------------------------------------
# Crop which required very high ratio of potassium content in soil: ['grapes' 'apple']
# -----------------------------------------------------------------------------------------------------
# Crop which required very high Rainfall: ['rice' 'papaya' 'coconut']
# -----------------------------------------------------------------------------------------------------
# Crop which required very high Temperature: ['grapes' 'papaya']
# -----------------------------------------------------------------------------------------------------
# Crop which required very low Temperature: ['grapes']
# ...

# %%
sb.pairplot(data,hue='Label')
